# %%
import pandas as pd
df=pd.read_csv('/content/water_potability.csv')
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.isna().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df.isna().transpose()
# Out:
#                   0      1      2      3      4      5      6      7     \
# ph                True  False  False  False  False  False  False  False
# Hardness         False  False  False  False  False  False  False  False
# Solids           False  False  False  False  False  False  False  False
# Chloramines      False  False  False  False  False  False  False  False
# Sulfate          False   True   True  False  False  False  False  False
# Conductivity     False  False  False  False  False  False  False  False
# Organic_carbon   False  False  False  False  False  False  False  False
# Trihalomethanes  False  False  False  False  False  False  False  False
# Turbidity        False  False  False  False  False  False  False  False
# Potability       False  False  False  False  False  False  False  False
#
#                   8      9     ...   3266   3267   3268   3269   3270   3271  \
# ph                True  False  ...  False  False  False  False  False  False
# ...

# %%
import seaborn as sns
sns.heatmap(df.isna().transpose())
# Out:
# <Axes: >

# %%
df.drop(["ph","Sulfate"],axis=1,inplace=True)

# %%
df
# Out:
#         Hardness        Solids  Chloramines  Conductivity  Organic_carbon  \
# 0     204.890455  20791.318981     7.300212    564.308654       10.379783
# 1     129.422921  18630.057858     6.635246    592.885359       15.180013
# 2     224.236259  19909.541732     9.275884    418.606213       16.868637
# 3     214.373394  22018.417441     8.059332    363.266516       18.436524
# 4     181.101509  17978.986339     6.546600    398.410813       11.558279
# ...          ...           ...          ...           ...             ...
# 3271  193.681735  47580.991603     7.166639    526.424171       13.894419
# 3272  193.553212  17329.802160     8.061362    392.449580       19.903225
# 3273  175.762646  33155.578218     7.350233    432.044783       11.039070
# 3274  230.603758  11983.869376     6.303357    402.883113       11.168946
# 3275  195.102299  17404.177061     7.509306    327.459760       16.140368
#
#       Trihalomethanes  Turbidity  Potability
# ...

# %%
df.Trihalomethanes
# Out:
# 0        86.990970
# 1        56.329076
# 2        66.420093
# 3       100.341674
# 4        31.997993
#            ...
# 3271     66.687695
# 3272           NaN
# 3273     69.845400
# 3274     77.488213
# 3275     78.698446
# Name: Trihalomethanes, Length: 3276, dtype: float64

# %%
df.Potability.value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
#To handle the missing value

# %%
sns.boxplot(df['Trihalomethanes'])
# Out:
# <Axes: >

# %%
# Since the data is normally distributed and has outliers median is used to fill the missing value

# %%
df.Trihalomethanes.median()
# Out:
# 66.62248509808484

# %%
df.fillna(value=66.62248509808484,inplace=True)

# %%
df.Trihalomethanes.isna().sum()
# Out:
# 0

# %%
X=df.drop('Potability',axis=1)
y=df.Potability

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=40)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=5000)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
MSE = mean_squared_error(y_test, y_pred)
MAE = mean_absolute_error(y_test, y_pred)
r2_score = r2_score(y_test, y_pred)
print(f"MSE = {MSE}")
print(f"MAE = {MAE}")
print(f"r2_score = {r2_score}")
# Out:
# MSE = 0.39939024390243905
# MAE = 0.39939024390243905
# r2_score = -0.6671225568650276

# %%
df
# Out:
#         Hardness        Solids  Chloramines  Conductivity  Organic_carbon  \
# 0     204.890455  20791.318981     7.300212    564.308654       10.379783
# 1     129.422921  18630.057858     6.635246    592.885359       15.180013
# 2     224.236259  19909.541732     9.275884    418.606213       16.868637
# 3     214.373394  22018.417441     8.059332    363.266516       18.436524
# 4     181.101509  17978.986339     6.546600    398.410813       11.558279
# ...          ...           ...          ...           ...             ...
# 3271  193.681735  47580.991603     7.166639    526.424171       13.894419
# 3272  193.553212  17329.802160     8.061362    392.449580       19.903225
# 3273  175.762646  33155.578218     7.350233    432.044783       11.039070
# 3274  230.603758  11983.869376     6.303357    402.883113       11.168946
# 3275  195.102299  17404.177061     7.509306    327.459760       16.140368
#
#       Trihalomethanes  Turbidity  Potability
# ...

# %%
pur=model.predict([[204.890455,20791.318981,7.300212,564.308654,10.379783,86.990970,2.963135]])
pur[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 0

# %%
pur=model.predict([[195.102299,17404.177061,7.509306,327.459760,16.140368,78.698446,2.309149]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
pur[0]
# Out:
# 0

# %%
from sklearn.tree import DecisionTreeClassifier
dt= DecisionTreeClassifier(criterion='gini',min_samples_split=10,splitter='best')
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(min_samples_split=10)

# %%
prediction=dt.predict(X_test)

# %%
res=dt.predict([[195.102299,17404.177061,7.509306,327.459760,16.140368,78.698446,2.309149]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
res
# Out:
# array([1])

# %%
res[0]
# Out:
# 1
